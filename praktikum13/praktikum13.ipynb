# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

import torch
from torch import nn, optim
from jcopdl.callback import Callback, set_config

from jcopdl.utils.dataloader import TimeSeriesDataset 
from torch.utils.data import DataLoader
import os

from tqdm.auto import tqdm
from sklearn.preprocessing import MinMaxScaler

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") 
print("Device:", device)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 10
#       7 from torch import nn, optim
#       8 from jcopdl.callback import Callback, set_config
# ---> 10 from jcopdl.utils.dataloader import TimeSeriesDataset
#      11 from torch.utils.data import DataLoader
#      12 import os
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\jcopdl\utils\__init__.py:3
#       1 from .random_state import set_pytorch_random_state
#       2 from ._conv import conv_output_size, tconv_output_size
# ----> 3 from .dataloader import TimeSeriesDataset, MultilabelDataset, CocoDetectionDataset, CocoDetectionDataloader
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\jcopdl\utils\dataloader\__init__.py:3
#       1 from ._time_series import TimeSeriesDataset
#       2 from ._multilabel import MultilabelDataset
# ----> 3 from ._coco_detection import CocoDetectionDataset, CocoDetectionDataloader
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\jcopdl\utils\dataloader\_coco_detection.py:5
#       3 import torch
#       4 from torch.utils.data import DataLoader
# ----> 5 from torchvision.datasets.coco import CocoDetection
#       6 import matplotlib.pyplot as plt
#       9 class CocoDetectionDataset(CocoDetection):
#
# ModuleNotFoundError: No module named 'torchvision'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
